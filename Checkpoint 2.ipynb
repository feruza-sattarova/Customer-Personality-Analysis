# %% [markdown]
# # Checkpoint Two: Exploratory Data Analysis
#
# Now that your chosen dataset is approved, it is time to start working on your analysis. Use this notebook to perform your EDA and make notes where directed to as you work.
#
# ## Getting Started
#
# Since we have not provided your dataset for you, you will need to load the necessary files in this repository. Make sure to include a link back to the original dataset here as well.
#
# Name of my dataset: Customer Personality Analysis,
# Link to my dataset: https://www.kaggle.com/datasets/imakash3011/customer-personality-analysis
#
# Your first task in EDA is to import necessary libraries and create a dataframe(s). Make note in the form of code comments of what your thought process is as you work on this setup task.

# %%
# Importing the appropriate libraries with aliases
import numpy as np 
import pandas as pd 
from scipy import stats
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
from datetime import datetime
import plotly.express as px

# Creating a dataframe:
data = pd.read_csv('marketing_campaign.csv')

# %% [markdown]
# ## Get to Know the Numbers
#
# Now that you have everything setup, put any code that you use to get to know the dataframe and its rows and columns better in the cell below. You can use whatever techniques you like, except for visualizations. You will put those in a separate section.
#
# When working on your code, make sure to leave comments so that your mentors can understand your thought process.

# %%
# Checking what is in the dataframe (displaying top 20 rows):
data.head(10)
# Out:
#      ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0  5524        1957  Graduation          Alone  58138.0        0         0
# 1  2174        1954  Graduation          Alone  46344.0        1         1
# 2  4141        1965  Graduation      Not Alone  71613.0        0         0
# 3  6182        1984  Graduation      Not Alone  26646.0        1         0
# 4  5324        1981         PhD      Not Alone  58293.0        1         0
# 5  7446        1967      Master      Not Alone  62513.0        0         1
# 6   965        1971  Graduation          Alone  55635.0        0         1
# 7  6177        1985         PhD      Not Alone  33454.0        1         0
# 8  4855        1974         PhD      Not Alone  30351.0        1         0
# 9  5899        1950         PhD      Not Alone   5648.0        1         1
#
#   Dt_Customer  Recency  MntWines  ...  AcceptedCmp2  Complain  Z_CostContact  \
# 0    4/9/2012       58       635  ...             0         0              3
# 1    8/3/2014       38        11  ...             0         0              3
# 2  21-08-2013       26       426  ...             0         0              3
# 3   10/2/2014       26        11  ...             0         0              3
# 4  19-01-2014       94       173  ...             0         0              3
# 5    9/9/2013       16       520  ...             0         0              3
# 6  13-11-2012       34       235  ...             0         0              3
# 7    8/5/2013       32        76  ...             0         0              3
# 8    6/6/2013       19        14  ...             0         0              3
# 9  13-03-2014       68        28  ...             0         0              3
#
#    Z_Revenue  Response  Age  Education_Level  Total_transactions  Spent  \
# 0         11         1   66             High                  22   1617
# 1         11         0   69             High                   4     27
# 2         11         0   58             High                  20    776
# 3         11         0   39             High                   6     53
# 4         11         0   42             High                  14    422
# 5         11         0   56             High                  20    716
# 6         11         0   52             High                  17    590
# 7         11         0   38             High                   8    169
# 8         11         1   49             High                   5     46
# 9         11         0   73             High                   1     49
#
#    online-ratio
# 0      0.363636
# 1      0.250000
# 2      0.400000
# 3      0.333333
# 4      0.357143
# 5      0.300000
# 6      0.411765
# 7      0.500000
# 8      0.600000
# 9      1.000000
#
# [10 rows x 34 columns]

# %%
#Checking the unique education status of all customers:

unique_edu = data['Education'].drop_duplicates()
print(unique_edu)
# Out:
# 0     Graduation
# 4            PhD
# 5         Master
# 11         Basic
# 19      2n Cycle
# Name: Education, dtype: object

# %%
#Checking the null values:

data.isnull().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# dtype: int64

# %%
#Filling the null values with median value:

data['Income']=data['Income'].fillna(data['Income'].median())
print(f'NULL values: {data["Income"].isnull().sum()}')
# Out:
# NULL values: 0

# %%
# Identifying the age of all customers:
data['Age'] = datetime.now().year - data['Year_Birth']
data['Age']
# Out:
# 0       66
# 1       69
# 2       58
# 3       39
# 4       42
#         ..
# 2235    56
# 2236    77
# 2237    42
# 2238    67
# 2239    69
# Name: Age, Length: 2240, dtype: int64

# %%
# Identifying customers older than 82:
data.query('Age>82')
# Out:
#          ID  Year_Birth Education Marital_Status   Income  Kidhome  Teenhome  \
# 192    7829        1900  2n Cycle       Divorced  36640.0        1         0
# 239   11004        1893  2n Cycle         Single  60182.0        0         1
# 339    1150        1899       PhD       Together  83532.0        0         0
# 1950   6663        1940       PhD         Single  51141.0        0         0
#
#      Dt_Customer  Recency  MntWines  ...  AcceptedCmp3  AcceptedCmp4  \
# 192   26-09-2013       99        15  ...             0             0
# 239   17-05-2014       23         8  ...             0             0
# 339   26-09-2013       36       755  ...             0             0
# 1950    8/7/2013       96       144  ...             0             0
#
#       AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Complain  Z_CostContact  \
# 192              0             0             0         1              3
# 239              0             0             0         0              3
# 339              1             0             0         0              3
# 1950             0             0             0         0              3
#
#       Z_Revenue  Response  Age
# 192          11         0  123
# 239          11         0  130
# 339          11         0  124
# 1950         11         0   83
#
# [4 rows x 30 columns]

# %%
# Education level will be segmented into 3 categories only for better segmentaion:

#def Education_level(Education):
#    if Education in ['Graduation', 'PhD', 'Master']:
#        return 'High'
#   elif Education in ['Basic']:
#       return 'Middle'
#   else:
#       return 'Low'

# Education level will be segmented into 4 categories only for better segmentaion:
    
def Education_level(Education):
    if Education in ['PhD']:
        return 'PhD'
    elif Education in ['2n Cycle', 'Master']:
        return 'Master'
    elif Education in ['Graduation']:
        return 'UnderGraduate'
    else:
        return 'High School'

data['Education_Level'] = data['Education'].apply(Education_level)

# %%
#Marital Status will be segmented into two categories only (alone,not alone):
data['Marital_Status'] = data['Marital_Status'].replace({'Alone':'Alone', 'Absurd':'Alone','YOLO':'Alone','Single':'Alone','Divorced':'Alone','Widow':'Alone','Married':'Not Alone','Together':'Not Alone'})

# %%
#Total transactions:
data['Total_transactions'] = data['NumWebPurchases'] + data['NumCatalogPurchases'] + data['NumStorePurchases']

# %%
#Total spent by customers:
data['Spent'] = data[['MntFruits','MntMeatProducts',"MntWines",'MntFishProducts','MntSweetProducts',
                      'MntGoldProds']].sum(axis=1)

# %%
#Online sales  ratio:
data['online-ratio'] = data['NumWebPurchases'] / (data['NumWebPurchases'] + data['NumCatalogPurchases'] + data['NumStorePurchases'])

# %%
#Total transactions:
data['Total_transactions'] = data['NumWebPurchases'] + data['NumCatalogPurchases'] + data['NumStorePurchases']

# %% [markdown]
# ## Visualize
#
# Create any visualizations for your EDA here. Make note in the form of code comments of what your thought process is for your visualizations.

# %%
# Visualizing customers by their age:
data.Age.hist(bins=16)
plt.title('Customers age', fontsize=14)
plt.show()

# %%
#Visualizing the level of education of all customers:

data['Education_Level'].value_counts().plot(kind='bar',linewidth = 3)
plt.title("Frequency of education status \n",fontsize=18)
# plt.grid(True)
plt.show()

# %%
#Customer income
sns.boxplot(data.Income)
plt.title('Customers income', fontsize=14)
plt.show()

# %%
#Visualizing the proportion of sales by product categories:

sales_sections = ['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']
totals = data[sales_sections].sum()
average_proportions = totals / data['Spent'].sum()

fig, ax = plt.subplots()
ax.pie(average_proportions, labels=sales_sections,autopct='%1.1f%%')
plt.title('Average Proportion of sales_sections ')
plt.show()

# %%
g = sns.FacetGrid(data ,aspect=2 ,height=4)
g.map(sns.barplot,"Education_Level","Income")
g.add_legend()
plt.xticks(rotation='vertical')
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'UnderGraduate'),
#   Text(1, 0, 'PhD'),
#   Text(2, 0, 'Master'),
#   Text(3, 0, 'High School')])

# %%
#Store purchases by marital status:
fig_3 = px.bar(data, x="Age", y="NumStorePurchases",color='Marital_Status')
fig_3.show()
# Out:
# <div>                            <div id="d08a42f5-2e61-41e1-8870-a0066cbbb70e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d08a42f5-2e61-41e1-8870-a0066cbbb70e")) {                    Plotly.newPlot(                        "d08a42f5-2e61-41e1-8870-a0066cbbb70e",                        [{"alignmentgroup":"True","hovertemplate":"Marital_Status=Alone<br>Age=%{x}<br>NumStorePurchases=%{y}<extra></extra>","legendgroup":"Alone","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Alone","offsetgroup":"Alone","orientation":"v","showlegend":true,"textposition":"auto","x":[66,69,52,64,71,77,38,54,37,34,71,72,50,80,64,47,72,66,46,46,57,35,41,41,71,72,44,46,47,38,36,66,66,51,63,51,63,64,45,32,32,61,56,47,40,39,65,47,50,58,31,49,35,65,45,68,65,48,70,64,35,56,53,123,50,71,55,45,58,39,60,69,45,69,61,71,57,61,72,65,50,130,55,52,48,38,49,49,59,59,66,44,55,70,40,60,67,37,55,57,74,35,41,58,65,35,57,76,47,47,38,53,58,62,70,47,37,40,34,63,55,35,37,71,53,52,57,47,45,54,54,47,48,53,57,51,48,53,34,54,69,42,52,55,30,36,67,49,68,51,52,41,36,42,62,53,57,74,34,64,51,59,68,52,57,74,65,54,53,35,51,51,49,59,71,47,59,79,61,45,70,34,64,44,48,33,58,36,59,48,54,41,56,42,54,39,59,60,34,52,45,43,60,61,44,45,68,39,58,54,62,68,37,50,67,54,79,54,58,45,52,74,45,48,46,46,63,50,61,71,73,64,59,53,63,68,48,57,48,36,61,53,48,44,43,60,56,47,51,63,53,74,28,74,62,50,45,35,55,53,72,58,48,63,53,65,47,74,75,50,70,73,28,53,48,56,45,71,58,58,68,52,49,53,55,47,73,62,61,58,67,79,51,51,48,69,43,62,64,61,65,47,31,51,43,43,46,35,32,67,60,49,44,48,57,37,64,42,52,67,51,48,51,70,45,58,32,80,51,65,37,53,46,62,52,57,60,29,69,69,30,54,41,30,34,72,71,52,48,71,40,37,44,48,50,52,71,66,56,61,64,63,58,44,45,47,67,69,34,69,28,67,67,36,69,60,45,47,45,36,65,52,43,51,32,58,53,38,71,36,50,31,58,67,55,58,53,53,65,49,51,44,65,37,48,63,69,40,50,63,39,55,50,44,61,57,38,71,56,38,61,34,45,61,78,37,80,60,54,42,32,62,65,52,38,71,53,54,63,71,55,62,44,48,58,60,37,66,65,68,52,45,71,39,61,52,31,60,50,40,71,48,65,60,51,55,45,52,53,52,46,60,45,53,67,61,46,41,75,71,41,41,48,61,30,61,77,60,52,49,46,65,47,55,48,58,63,63,48,68,59,48,49,51,55,66,70,33,44,51,57,65,51,50,50,56,75,70,56,52,53,73,60,57,67,36,44,47,73,46,50,68,48,43,53,40,47,50,75,36,48,35,34,64,56,70,59,60,66,72,47,62,47,69,71,59,77,32,47,73,36,50,56,50,39,68,33,35,33,48,36,64,52,60,69,59,63,42,56,73,62,60,76,45,42,65,47,57,34,38,38,44,43,52,34,72,36,42,71,66,72,34,31,67,32,61,41,44,58,68,65,69,56,78,54,54,43,74,52,44,52,44,43,49,38,38,44,47,56,60,47,68,46,57,57,59,49,60,69,72,52,52,58,36,69,70,55,35,28,39,52,72,48,44,50,39,56,59,51,75,71,36,64,48,55,54,38,39,52,55,49,74,69,78,40,52,53,60,55,42,47,46,67,80,64,66,67,74,46,72,55,83,72,59,73,67,33,73,61,71,57,74,57,40,55,39,49,48,60,76,65,43,53,56,57,51,59,64,65,37,65,72,70,76,72,32,53,53,53,48,64,68,58,50,47,42,72,36,53,63,68,80,43,49,30,67,53,62,68,61,52,47,47,66,54,53,69,57,49,55,50,66,54,59,58,74,31,49,69,33,42,58,53,56,50,45,40,52,71,49,33,54,50,55,60,68,73,28,75,41,53,61,39,53,37,42],"xaxis":"x","y":[4,2,7,8,5,12,3,3,0,3,6,3,3,5,4,9,4,10,3,7,10,4,3,11,10,8,10,2,9,4,13,6,2,3,6,3,3,3,3,5,11,3,3,3,13,6,6,3,2,3,12,9,4,5,3,10,2,10,4,6,7,2,4,2,3,7,9,9,3,2,5,9,2,5,12,11,8,4,3,11,3,2,10,2,3,3,13,3,7,4,2,2,10,5,4,4,10,8,9,5,5,3,6,12,3,4,3,10,3,10,6,10,2,5,8,4,4,2,3,12,6,11,4,4,6,3,5,5,3,10,9,3,8,2,12,3,2,2,3,3,6,2,2,12,6,3,3,5,6,4,5,3,7,9,9,4,12,5,3,2,4,7,11,4,9,11,3,9,2,2,3,3,2,13,4,5,3,6,11,3,12,11,12,12,9,3,3,6,4,8,5,3,4,3,4,3,4,3,2,8,11,7,7,9,2,3,5,2,9,3,3,9,2,3,3,6,7,13,3,3,2,6,3,7,3,4,3,7,2,11,9,6,4,6,9,5,0,3,13,3,9,6,8,12,13,4,13,11,10,7,4,2,2,3,6,5,11,7,4,3,6,10,3,8,9,2,11,3,4,4,11,3,12,2,13,8,2,5,7,3,3,5,10,2,4,5,3,5,7,8,3,13,6,3,6,4,8,7,11,3,4,3,7,5,12,3,5,4,8,8,5,3,12,4,8,2,4,4,4,12,2,3,10,4,10,5,2,5,5,7,3,4,10,7,2,8,10,7,7,9,6,4,10,6,4,10,5,11,9,5,6,3,5 ...

# %% [markdown]
# ## Summarize Your Results
#
# With your EDA complete, answer the following questions.
#
# 1. Was there anything surprising about your dataset?
# 2. Do you have any concerns about your dataset?
# 3. Is there anything you want to make note of for the next phase of your analysis, which is cleaning data?

# %%
1. Was there anything surprising about your dataset? 
I was surprised to see that the amount of alcohol sold (50.2%) exceeds the amount of food sold. 

2. Do you have any concerns about your dataset?
The dataset looks good and fun to work with. 

3. Is there anything you want to make note of for the next phase of your analysis, which is cleaning data?
I have performed some cleaning in this stage, including filling the null values in the 'Income' field with the median value. 
In the next stage, I will check for duplicates, outliers, incomplete data, and other issues.
# Out:
#   Cell In[52], line 1
#     1. Was there anything surprising about your dataset?
#        ^
# SyntaxError: invalid syntax
